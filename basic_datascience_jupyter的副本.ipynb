# %%
#print("Hello World")

# %%
# 5+8

# %%
x=-23.48

# %%
#x

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
My_first_dataframe=pd.DataFrame({ 'col1': [1, 2, 1.5], 'col2': [3, 4, 6] })   
My_first_dataframe
# Out:
#    col1  col2
# 0   1.0     3
# 1   2.0     4
# 2   1.5     6

# %% [markdown]
# ### Lets plot My_first_Dataframe

# %%
My_first_dataframe.plot(figsize=(3,3))

plt.ylabel('value')
plt.xlabel('index (row)')

plt.show()

# %% [markdown]
# ### Lets plot a sinus curve

# %%
x=np.linspace(0,10,20)  # 20 elements in the 1D array x
x
x[0]   # note index starts from 0
x[19]
# Out:
# 10.0

# %%
y=3*np.sin(0.8*x+5)
y
# Out:
# array([-2.87677282, -2.27769683, -1.28074916, -0.06007822,  1.17108728,
#         2.19768541,  2.8403884 ,  2.98692787,  2.61170607,  1.78026735,
#         0.63784873, -0.61599031, -1.7622272 , -2.60063547, -2.98476063,
#        -2.84750312, -2.21283927, -1.19163318,  0.03772927,  1.26050111])

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### scatterplot of some data (2D array):

# %%
data=np.array([[2,1],[6,-2],[-1,-3]])
data
x_coord=data[:,0]
x_coord
y_coord=data[:,1]
y_coord
# Out:
# array([ 1, -2, -3])

# %%
plt.scatter(x_coord,y_coord)
plt.show()

# %% [markdown]
# ### scatterplot of some data (dataframe)

# %%
data2=pd.DataFrame(data,columns=('x_coord','y_coord'))
data2
# Out:
#    x_coord  y_coord
# 0        2        1
# 1        6       -2
# 2       -1       -3

# %%
data2.shape
# Out:
# (3, 2)

# %%
data2.plot.scatter(x='x_coord',y='y_coord')
plt.show()

# %% [markdown]
# ### different colors of the datapoints:

# %%
data2['colors']=[0,1,2]
data2
# Out:
#    x_coord  y_coord  colors
# 0        2        1       0
# 1        6       -2       1
# 2       -1       -3       2

# %%
data2.shape
# Out:
# (3, 3)

# %%
data2.plot.scatter(x='x_coord',y='y_coord',c='colors',colormap='viridis')
plt.show()
